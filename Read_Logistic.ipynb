# %%
import numpy as np 
import pandas as pd 
from sklearn.linear_model import LogisticRegression 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("sample_data.csv")
print(data.head())
# Out:
#    Hours_Studied  Attendance  Prev_score  Final_marks  Pass
# 0              2          60          45           48     0
# 1              4          65          50           52     0
# 2              6          70          55           58     0
# 3              8          75          60           65     1
# 4             10          80          65           72     1

# %%
x=data[['Hours_Studied']]
y=data['Pass']

# %%
model=LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
result=model.predict([[5]])
prob=model.predict_proba([[5]])
# Out:
# E:\anaconda3\envs\ml_lab\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# E:\anaconda3\envs\ml_lab\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print("Pass/Fail:",result[0])
print("Probability:",prob)
# Out:
# Pass/Fail: 0
# Probability: [[0.87219713 0.12780287]]

# %%
x_range=np.linspace(x.min(),x.max(),100).reshape(-1,1)
prob=model.predict_proba(x_range)[:,1]
# Out:
# E:\anaconda3\envs\ml_lab\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.figure()
plt.scatter(x,y)
plt.plot(x_range,prob)
plt.xlabel("Hours Studied")
plt.ylabel("Probability of Passing")
plt.title("Logistic Regression: Sigmoid Curve")
plt.show()
