# %%
import numpy as np 
import pandas as pd 
from sklearn.linear_model import LinearRegression 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("sample_data.csv")
print(data.head())
# Out:
#    Hours_Studied  Attendance  Prev_score  Final_marks  Pass
# 0              2          60          45           48     0
# 1              4          65          50           52     0
# 2              6          70          55           58     0
# 3              8          75          60           65     1
# 4             10          80          65           72     1

# %%
x=data[['Hours_Studied']] 
y=data['Final_marks']

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=model.predict([[15]])
print("Predicted marks for 15 hours:",pred[0])
# Out:
# Predicted marks for 15 hours: 85.75757575757575
# E:\anaconda3\envs\ml_lab\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x_range=np.linspace(x.min(),x.max(),100)
y_pred=model.predict(x_range)
# Out:
# E:\anaconda3\envs\ml_lab\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.figure()
plt.scatter(x,y)
plt.plot(x_range,y_pred)
plt.xlabel("Hours Studied")
plt.ylabel("Final Marks")
plt.title("Linear Regression: Hours Studied vs Final Marks")
plt.show()
